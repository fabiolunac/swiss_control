# %%
from src.database import load_gastos, load_param
from src.transform_db import prepare_data
import pandas as pd
import numpy as np

df_raw   = load_gastos()
df_param = load_param()

df = prepare_data(df_raw, df_param)

df
# Out:
#         id       Data           Local  Valor Banco   Tipo    Categoria  \
# 0      155 2025-02-07       Carrefour  23.55   yuh  Gasto      Mercado
# 1      156 2025-02-08             TPG  45.00   yuh  Gasto        Extra
# 2      157 2025-02-08            CERN  10.90   yuh  Gasto  Alimentação
# 3      158 2025-02-08       Carrefour   8.41   yuh  Gasto      Mercado
# 4      159 2025-02-08           Hotel   0.67   yuh  Gasto        Extra
# ...    ...        ...             ...    ...   ...    ...          ...
# 1257  1267 2026-05-30    Caves Ouvert  13.50   yuh  Gasto        Extra
# 1258  1268 2026-05-30   Les Brasseurs   4.50   yuh  Gasto        Extra
# 1259  1269 2026-05-30   Les Brasseurs  42.70   yuh  Gasto        Extra
# 1260  1271 2026-05-30          Migros   9.95   yuh  Gasto      Mercado
# 1261  1272 2026-05-30  Tabac Servette  20.70   yuh  Gasto        Extra
#
#      Pagamento? Mês Pagamento  Ano Pagamento    Saldo Mês Pagamento Atual?  \
# 0           Não       2025-02           2025  3486.00                  Não
# 1           Não       2025-02           2025  3441.00                  Não
# 2           Não       2025-02           2025  3430.10                  Não
# 3           Não       2025-02           2025  3421.69                  Não
# 4           Não       2025-02           2025  3421.02                  Não
# ...         ...           ...            ...      ...                  ...
# 1257        Não       2026-06           2026  1815.62                  Sim
# 1258        Não       2026-06           2026  1811.12                  Sim
# 1259        Não       2026-06           2026  1768.42                  Sim
# 1260        Não       2026-06           2026  1758.47                  Sim
# 1261        Não       2026-06           2026  1737.77                  Sim
#
#      Ano Pagamento Atual?
# 0                     Não
# 1                     Não
# 2                     Não
# 3                     Não
# 4                     Não
# ...                   ...
# 1257                  Sim
# 1258                  Sim
# 1259                  Sim
# 1260                  Sim
# 1261                  Sim
#
# [1262 rows x 13 columns]
